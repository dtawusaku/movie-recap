# %%
import os , datetime , calendar , pandas as pd , seaborn as sns , matplotlib.pyplot as plt

# %%
movie_data = pd.read_csv('watched-movies.csv', index_col=0)

movie_data
# Out:
#                                                                                               Summary  \
# Title
# Murder Mystery 2                                    Full-time detectives Nick and Audrey are strug...
# Tetris                                              The story of how one of the world's most popul...
# Creed III                                           Adonis has been thriving in both his career an...
# Shazam! Fury of the Gods                            The film continues the story of teenage Billy ...
# Black Panther: Wakanda Forever                      The people of Wakanda fight to protect their h...
# Puss in Boots: The Last Wish                        When Puss in Boots discovers that his passion ...
# Ant-Man and the Wasp: Quantumania                   Scott Lang and Hope Van Dyne are dragged into ...
# Avatar: The Way of Water                            Jake Sully lives with his newfound family form...
# ...
